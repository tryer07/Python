# %%
#输入jupyter notebook这个指令可以在浏览器打开jupyter notebook并进行代码开发(一般不使用)
a = 100
b = 200
c = 300
a + b + c
# Out:
# 600

# %%
x = 1000
y = 2000
x + y
# Out:
# 3000

# %%
d = 100
e = 200
d + e
# Out:
# 300

# %%
x = 1000
y = 2000
x * y
# Out:
# 2000000
